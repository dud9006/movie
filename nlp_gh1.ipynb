# %%
from glob import glob
import datetime
import plotly

from konlpy.tag import Okt
from collections import Counter
from wordcloud import WordCloud
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
file = open("headline1.txt",encoding='UTF-8')

# %%
lists = file.readlines()

# %%
file.close()

# %%
lists
# Out:
# [',0\n',
#  "0,지만원 '거짓 판명' 5·18 北 개입설 또 반복…비난 쇄도\n",
#  '1,한국당 “손혜원 국조 받아라”…민주 “의혹 있는 모든의원 다…\n',
#  '2,“정책 나올때마다 시장왜곡 우려” “주52시간도 또하나의 규…\n',
#  '3,"""朴 전대통령 건강 좋지 않지만… 위독설·체중39㎏은 사실 …"\n',
#  '4,"文대통령 ""예타 제도 유지…균형발전 위해 개선 필요 있어"""\n',
#  '5,[벼랑끝 공인중개사②]온ㆍ오프라인서 동반 위협…거래절벽…\n',
#  '6,작년 세금 계획보다 25.4조 더 걷혔다…역대 최대 초과 세수\n',
#  '7,초과 세수 25.4조 원 ‘사상 최대’…“반도체·부동산 호황 덕…\n',
#  '8,韓 외환보유액 4055억 달러 사상 최대…석달 연속 증가세(종…\n',
#  '9,"""내 택배 어디쯤 왔나""…\'택배 조회\' 종일 실검에 왜?"\n',
#  '10,이번엔 뚝섬 장어집 “골목식당 제작진이 사기꾼 만들어”… …\n',
#  "11,전국 대부분 지역 '한파주의보'…서울 체감온도 영하 14도\n",
#  '12,정부와 정치권에 경종 울린 두 의사의 죽음 [어떻게 생각하…\n',
#  '13,서울 국공립 중고교 교사 임용에 836명 합격…남성은 23%\n',
#  '14,"""한 명이라도 더 살려야""…끝까지 현장 지킨 \'응급의료 버팀…"\n',
#  '15,[날씨] 출근길 동장군 맹위…체감온도 영하 15도\n',
#  "16,[날씨] 전국 대부분 '한파주의보'...주말에도 강추위 계속\n",
#  '17,설 연휴 인천공항 하루평균 이용객 20만명 넘어…역대 최다\n',
#  '18,"""너도 스테로이드 했지?""…피트니스계에 번지는 \'약투\'"\n',
#  '19,[날씨] 주말ㆍ휴일 내내 한겨울 추위…건조특보 확대\n',
#  '20,"베네수엘라, 물고 물린 \'쩐의 전쟁\'"\n',
#  "21,2월 미중 정상회담 무산 배경은?…'북미회담과 분리 의도'\n",
# ...

# %%
print(type(lists))
# Out:
# <class 'list'>

# %%
data = ''.join(lists)

# %%
print(type(data))
# Out:
# <class 'str'>

# %%
news = data.replace("\n","")
#news

# %%
# %matplotlib inline
from matplotlib import rc
import matplotlib.pyplot as plt
rc('font', family='NanumGothic')

# %%
from wordcloud import WordCloud

# %%
print(type(news))
# Out:
# <class 'str'>

# %%
wcloud = WordCloud('./data/D2Coding.ttf',relative_scaling = 0.2).generate(news)
plt.figure(figsize=(12,12))
plt.imshow(wcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
news1=news

# %% [markdown]
# ### sent_tokenize는 실패

# %%
from nltk import sent_tokenize
text=sent_tokenize(news)

# %%
#text

# %% [markdown]
# ### regex를 이용한 토큰화

# %%
from nltk.tokenize import RegexpTokenizer
re_capt = RegexpTokenizer('[가-힣]\w+')

# %%
news2=re_capt.tokenize(news)

# %%
news1==news2
# Out:
# False

# %%
news2
# Out:
# ['지만원',
#  '거짓',
#  '판명',
#  '개입설',
#  '반복',
#  '비난',
#  '쇄도1',
#  '한국당',
#  '손혜원',
#  '국조',
#  '받아라',
#  '민주',
#  '의혹',
#  '있는',
#  '모든의원',
#  '정책',
#  '나올때마다',
#  '시장왜곡',
#  '우려',
#  '주52시간도',
#  '또하나의',
#  '전대통령',
#  '건강',
#  '좋지',
#  '않지만',
#  '위독설',
#  '체중39',
#  '사실',
#  '대통령',
#  '예타',
#  '제도',
#  '유지',
#  '균형발전',
#  '위해',
#  '개선',
#  '필요',
#  '있어',
#  '벼랑끝',
#  '공인중개사②',
#  '온ㆍ오프라인서',
#  '동반',
#  '위협',
#  '거래절벽',
#  '작년',
#  '세금',
#  '계획보다',
#  '걷혔다',
#  '역대',
#  '최대',
#  '초과',
#  '세수7',
#  '초과',
#  '세수',
#  '사상',
#  '최대',
#  '반도체',
#  '부동산',
#  '호황',
#  '외환보유액',
#  '달러',
#  '사상',
#  '최대',
#  '석달',
#  '연속',
#  '증가세',
#  '택배',
#  '어디쯤',
#  '왔나',
#  '택배',
#  '조회',
#  '종일',
#  '실검에',
#  '이번엔',
#  '뚝섬',
#  '장어집',
#  '골목식당',
#  '제작진이',
#  '사기꾼',
#  '만들어',
#  '전국',
#  '대부분',
#  '지역',
#  '한파주의보',
#  '서울',
#  '체감온도',
#  '영하',
#  '도12',
#  '정부와',
#  '정치권에',
#  '경종',
#  '울린',
#  '의사의',
#  '죽음',
#  '어떻게',
#  '생각하',
#  '서울',
#  '국공립',
#  '중고교',
#  '교사',
#  '임용에',
#  '합격',
#  '남성은',
# ...

# %%
print(type(news2))
# Out:
# <class 'list'>

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 

stop_words = "한국 속보 종합 단독 논란 날씨 만원 대통령"
# 위의 불용어는 명사가 아닌 단어 중에서 저자가 임의로 선정한 것으로 실제 의미있는 선정 기준이 아님
stop_words=stop_words.split(' ')
word_tokens =news2

news2=[word for word in word_tokens if not word in stop_words]

print(news2)
# Out:
# ['지만원', '거짓', '판명', '개입설', '반복', '비난', '쇄도1', '한국당', '손혜원', '국조', '받아라', '민주', '의혹', '있는', '모든의원', '정책', '나올때마다', '시장왜곡', '우려', '주52시간도', '또하나의', '전대통령', '건강', '좋지', '않지만', '위독설', '체중39', '사실', '예타', '제도', '유지', '균형발전', '위해', '개선', '필요', '있어', '벼랑끝', '공인중개사②', '온ㆍ오프라인서', '동반', '위협', '거래절벽', '작년', '세금', '계획보다', '걷혔다', '역대', '최대', '초과', '세수7', '초과', '세수', '사상', '최대', '반도체', '부동산', '호황', '외환보유액', '달러', '사상', '최대', '석달', '연속', '증가세', '택배', '어디쯤', '왔나', '택배', '조회', '종일', '실검에', '이번엔', '뚝섬', '장어집', '골목식당', '제작진이', '사기꾼', '만들어', '전국', '대부분', '지역', '한파주의보', '서울', '체감온도', '영하', '도12', '정부와', '정치권에', '경종', '울린', '의사의', '죽음', '어떻게', '생각하', '서울', '국공립', '중고교', '교사', '임용에', '합격', '남성은', '명이라도', '살려야', '끝까지', '현장', '지킨', '응급의료', '버팀', '출근길', '동장군', '맹위', '체감온도', '영하', '도16', '전국', '대부분', '한파주의보', '주말에도', '강추위', '계속17', '연휴', '인천공항', '하루평균', '이용객', '만명', '넘어', '역대', '최다18', '너도', '스테로이드', '했지', '피트니스계에', '번지는', '약투', '주말ㆍ휴일', '내내', '한겨울', '추위', '건조특보', '확대20', '베네수엘라', '물고', '물린', '쩐의', '전쟁', '미중',
# ...

# %%
'날씨' in news2
# Out:
# False

# %%
news3=' '.join(news2)
#스트링으로 형변환

# %%
print(type(news3))
# Out:
# <class 'str'>

# %%
news3
# Out:
# '지만원 거짓 판명 개입설 반복 비난 쇄도1 한국당 손혜원 국조 받아라 민주 의혹 있는 모든의원 정책 나올때마다 시장왜곡 우려 주52시간도 또하나의 전대통령 건강 좋지 않지만 위독설 체중39 사실 예타 제도 유지 균형발전 위해 개선 필요 있어 벼랑끝 공인중개사② 온ㆍ오프라인서 동반 위협 거래절벽 작년 세금 계획보다 걷혔다 역대 최대 초과 세수7 초과 세수 사상 최대 반도체 부동산 호황 외환보유액 달러 사상 최대 석달 연속 증가세 택배 어디쯤 왔나 택배 조회 종일 실검에 이번엔 뚝섬 장어집 골목식당 제작진이 사기꾼 만들어 전국 대부분 지역 한파주의보 서울 체감온도 영하 도12 정부와 정치권에 경종 울린 의사의 죽음 어떻게 생각하 서울 국공립 중고교 교사 임용에 합격 남성은 명이라도 살려야 끝까지 현장 지킨 응급의료 버팀 출근길 동장군 맹위 체감온도 영하 도16 전국 대부분 한파주의보 주말에도 강추위 계속17 연휴 인천공항 하루평균 이용객 만명 넘어 역대 최다18 너도 스테로이드 했지 피트니스계에 번지는 약투 주말ㆍ휴일 내내 한겨울 추위 건조특보 확대20 베네수엘라 물고 물린 쩐의 전쟁 미중 정상회담 무산 배경은 북미회담과 분리 의도 특파원리포트 대단한 중국인들 방콕 호텔 투숙하며 원정 언론 징용공 배상은 기업 문제 입장 크로아티아서 억원 넘는 장어 밀반출 한국인 체포25 유료방송 지각변동 속속 케이블TV 이진욱의 전자수첩 한국은 같은 미국보다 상처엔 연고 반창고 전자약 밴드 붙이면 국내 연구진 암세포의 림프절 전이 기전 최초 규명 차세 무슨 비밀대화 나누길래 카톡 깔고 텔레그램만 쓰는 지만원 거짓 판명 개입설 반복 비난 쇄도31 여야 폄훼 김진태 이종명 질타 출당 촉구도 하노이行 김정은 베트남 국빈방문 년만에 이뤄지나 북미 정상회담 개최지 베트남 하노이는 어떤 곳34 북미정상회담 시기 장소 완전히 확정 역할 억원 보복관세 부과할 있어 취재후 청춘을 바쳤는데 무너진 조선소 가족 착한 기업은 없는 걸까38 지난해는 역대 최대인데 냉온탕 우려 커지는 세수39 하버
# ...

# %%
wcloud = WordCloud('./data/D2Coding.ttf',relative_scaling = 0.2).generate(news3)
plt.figure(figsize=(12,12))
plt.imshow(wcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)
